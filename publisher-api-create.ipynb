# %%
import requests, random, string

# %%
class API(object):
    def __init__(self):
        self.base_path = "http://localhost:9090"
        self.client_session = requests.Session()
        self._getAccessToken()

    def _getAccessToken(self):
        form_data = {
            'username': 'admin',
            'password': 'admin',
            'grant_type': 'password',
            'scopes': 'apim:api_view apim:api_create'
        }
        self.client_session.post(self.base_path + "/publisher/auth/apis/login/token", data=form_data)
        self.access_token = self.client_session.cookies['WSO2_AM_TOKEN_1'] + self.client_session.cookies[
            'WSO2_AM_TOKEN_2']
        self.client_session.headers['Authorization'] = 'Bearer ' + self.access_token
        del self.client_session.cookies['WSO2_AM_TOKEN_1']
        del self.client_session.cookies['WSO2_AM_TOKEN_2']
        print("session headers: {}".format(self.client_session.headers))

    def createAPI(self, data):
        res = self.client_session.post(self.base_path + "/api/am/publisher/v1/apis", json=data)
        print("Status code: {}".format(res.status_code))

    def deleteAPI(self, uuid):
        res = self.client_session.delete(self.base_path + "/api/am/publisher/v1/apis/{}".format(uuid))
        print("Status code: {}".format(res.status_code))

    def getAll(self):
        res = self.client_session.get(self.base_path + "/api/am/publisher/v1/apis")
        print("Status code: {}".format(res.status_code))
        return res.json()

    def deleteAll(self):
        allApis = self.getAll()
        for api in allApis['list']:
            print("Deleting {}".format(api['name']))
            self.deleteAPI(api['id'])

# %%
class APITest(object):
    def __init__(self, debug=True):
        self.debub = debug
        self.api = API()

    def populateAPIs(self, count=10):
        template = {
            "name": None,
            "context": None,
            "version": "1.0.0",
            "apiDefinition": "{ \"paths\": { \"/*\": { \"get\": { \"description\": \"Global Get\" } } }, \"swagger\": \"2.0\" }",
            "cacheTimeout": 10,
            "transport": ["https"],
            "policies": ["Unlimited"],
            "visibility": "PUBLIC",
            "businessInformation": {},
            "corsConfiguration": {}
        }
        for index in range(count):
            random_char = random.choice(string.ascii_lowercase) + random.choice(string.ascii_lowercase)
            name_context = "{}sample_{}"
            template['name'] = template['context'] = name_context.format(random_char, index)
            self.api.createAPI(template)

# %%
tester = APITest()
# tester.populateAPIs(3)
tester.api.deleteAll()
# Out:
# session headers: {'Accept': '*/*', 'User-Agent': 'python-requests/2.9.1', 'Authorization': 'Bearer 44a6dfef-f030-4cbd-a486-a2def5548a12', 'Connection': 'keep-alive', 'Accept-Encoding': 'gzip, deflate'}
# Status code: 200
# Deleting kasun
# Status code: 200
# Deleting ljsample_0
# Status code: 200
# Deleting sampl
# Status code: 200

# %%
# %run -d
# Out:
# %run:
#  Run the named file inside IPython as a program.
#
# Usage::
#
#   %run [-n -i -e -G]
#        [( -t [-N<N>] | -d [-b<N>] | -p [profile options] )]
#        ( -m mod | file ) [args]
#
# Parameters after the filename are passed as command-line arguments to
# the program (put in sys.argv). Then, control returns to IPython's
# prompt.
#
# This is similar to running at a system prompt ``python file args``,
# but with the advantage of giving you IPython's tracebacks, and of
# loading all variables into your interactive namespace for further use
# (unless -p is used, see below).
#
# The file is executed in a namespace initially consisting only of
# ``__name__=='__main__'`` and sys.argv constructed as indicated. It thus
# sees its environment as if it were being run as a stand-alone program
# (except for sharing global objects such as previously imported
# modules). But after execution, the IPython interactive namespace gets
# ...

# %%
for a in range(5):
    # %debug
    print(a)
# Out:
# > <ipython-input-9-d0e2b3c72981>(2)<module>()
#       1 for a in range(5):
# ----> 2     d
#       3     print(a)
#
# ipdb> n
# 0
# > <ipython-input-9-d0e2b3c72981>(2)<module>()
#       1 for a in range(5):
# ----> 2     d
#       3     print(a)
#
# ipdb> a
# 1
# ipdb> f
# *** NameError: name 'f' is not defined
# ipdb> n
# 1
# > <ipython-input-9-d0e2b3c72981>(2)<module>()
#       1 for a in range(5):
# ----> 2     d
#       3     print(a)
#
# ipdb> a
# 2
# ipdb> s
# 2
# > <ipython-input-9-d0e2b3c72981>(2)<module>()
#       1 for a in range(5):
# ----> 2     d
#       3     print(a)
#
# ipdb> n
# 3
# > <ipython-input-9-d0e2b3c72981>(2)<module>()
#       1 for a in range(5):
# ----> 2     d
#       3     print(a)
